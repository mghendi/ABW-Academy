# %%
import sys
at_colab = "google.colab" in sys.modules

# %%
if at_colab:
    # !pip install fastkml
    # !pip install geopandas
    # !pip install rasterio
    # !pip install gadm
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting fastkml
#   Downloading fastkml-0.12-py3-none-any.whl (62 kB)
#      |████████████████████████████████| 62 kB 861 kB/s
# Collecting pygeoif<1.0
#   Downloading pygeoif-0.7.tar.gz (34 kB)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from fastkml) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil->fastkml) (1.15.0)
# Building wheels for collected packages: pygeoif
#   Building wheel for pygeoif (setup.py) ... done
#   Created wheel for pygeoif: filename=pygeoif-0.7-py3-none-any.whl size=19249 sha256=fa103b92dc250938af8d3618a8f73dc68d91652b3901b0bc204ac993f3cd6a8d
#   Stored in directory: /root/.cache/pip/wheels/4a/84/19/a1fcaf92f8f57a424eca18e2d8c03d149436806b91474bcb89
# Successfully built pygeoif
# Installing collected packages: pygeoif, fastkml
# Successfully installed fastkml-0.12 pygeoif-0.7
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting geopandas
#   Downloading geopandas-0.10.2-py2.py3-none-any.whl (1.0 MB)
#      |████████████████████████████████| 1.0 MB 4.0 MB/s
# Requirement already satisfied: shapely>=1.6 in /usr/local/lib/python3.7/dist-packages (from geopandas) (1.8.5.post1)
# Collecting pyproj>=2.2.0
#   Downloading pyproj-3.2.1-cp37-cp37m-manylinux2010_x86_64.whl (6.3 MB)
#      |████████████████████████████████| 6.3 MB 28.5 MB/s
# Collecting fiona>=1.8
#   Downloading Fiona-1.8.22-cp37-cp37m-manylinux2014_x86_64.whl (16.7 MB)
#      |████████████████████████████████| 16.7 MB 345 kB/s
# Requirement already satisfied: pandas>=0.25.0 in /usr/local/lib/python3.7/dist-packages (from geopandas) (1.3.5)
# Collecting click-plugins>=1.0
#   Downloading click_plugins-1.1.1-py2.py3-none-any.whl (7.5 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas) (57.4.0)
# Requirement already satisfied: six>=1.7 in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas) (1.15.0)
# Requirement already satisfied: click>=4.0 in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas) (7.1.2)
# Collecting cligj>=0.5
#   Downloading cligj-0.7.2-py3-none-any.whl (7.1 kB)
# Collecting munch
#   Downloading munch-2.5.0-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: attrs>=17 in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas) (22.1.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas) (2022.9.24)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.25.0->geopandas) (2022.6)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.25.0->geopandas) (1.21.6)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.25.0->geopandas) (2.8.2)
# Installing collected packages: munch, cligj, click-plugins, pyproj, fiona, geopandas
# Successfully installed click-plugins-1.1.1 cligj-0.7.2 fiona-1.8.22 geopandas-0.10.2 munch-2.5.0 pyproj-3.2.1
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting rasterio
#   Downloading rasterio-1.2.10-cp37-cp37m-manylinux1_x86_64.whl (19.3 MB)
#      |████████████████████████████████| 19.3 MB 81 kB/s
# Collecting snuggs>=1.4.1
#   Downloading snuggs-1.4.7-py3-none-any.whl (5.4 kB)
# Collecting affine
#   Downloading affine-2.3.1-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: attrs in /usr/local/lib/python3.7/dist-packages (from rasterio) (22.1.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from rasterio) (2022.9.24)
# Requirement already satisfied: click-plugins in /usr/local/lib/python3.7/dist-packages (from rasterio) (1.1.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from rasterio) (57.4.0)
# Requirement already satisfied: click>=4.0 in /usr/local/lib/python3.7/dist-packages (from rasterio) (7.1.2)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.7/dist-packages (from rasterio) (0.7.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from rasterio) (1.21.6)
# Requirement already satisfied: pyparsing>=2.1.6 in /usr/local/lib/python3.7/dist-packages (from snuggs>=1.4.1->rasterio) (3.0.9)
# Installing collected packages: snuggs, affine, rasterio
# Successfully installed affine-2.3.1 rasterio-1.2.10 snuggs-1.4.7
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting gadm
#   Downloading gadm-0.0.3-py3-none-any.whl (5.4 kB)
# Collecting types-requests
#   Downloading types_requests-2.28.11.5-py3-none-any.whl (14 kB)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from gadm) (4.1.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from gadm) (4.64.1)
# Requirement already satisfied: geopandas>=0.9.0 in /usr/local/lib/python3.7/dist-packages (from gadm) (0.10.2)
# Collecting types-setuptools
#   Downloading types_setuptools-65.6.0.0-py3-none-any.whl (48 kB)
#      |████████████████████████████████| 48 kB 2.3 MB/s
# Collecting pycountry>=22.3.5
#   Downloading pycountry-22.3.5.tar.gz (10.1 MB)
#      |████████████████████████████████| 10.1 MB 7.3 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from gadm) (2.23.0)
# Requirement already satisfied: pyproj>=2.2.0 in /usr/local/lib/python3.7/dist-packages (from geopandas>=0.9.0->gadm) (3.2.1)
# Requirement already satisfied: shapely>=1.6 in /usr/local/lib/python3.7/dist-packages (from geopandas>=0.9.0->gadm) (1.8.5.post1)
# Requirement already satisfied: fiona>=1.8 in /usr/local/lib/python3.7/dist-packages (from geopandas>=0.9.0->gadm) (1.8.22)
# Requirement already satisfied: pandas>=0.25.0 in /usr/local/lib/python3.7/dist-packages (from geopandas>=0.9.0->gadm) (1.3.5)
# Requirement already satisfied: click-plugins>=1.0 in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas>=0.9.0->gadm) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas>=0.9.0->gadm) (0.7.2)
# Requirement already satisfied: munch in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas>=0.9.0->gadm) (2.5.0)
# Requirement already satisfied: six>=1.7 in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas>=0.9.0->gadm) (1.15.0)
# Requirement already satisfied: click>=4.0 in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas>=0.9.0->gadm) (7.1.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas>=0.9.0->gadm) (57.4.0)
# Requirement already satisfied: attrs>=17 in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas>=0.9.0->gadm) (22.1.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas>=0.9.0->gadm) (2022.9.24)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.25.0->geopandas>=0.9.0->gadm) (1.21.6)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.25.0->geopandas>=0.9.0->gadm) (2022.6)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.25.0->geopandas>=0.9.0->gadm) (2.8.2)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->gadm) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->gadm) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->gadm) (2.10)
# Collecting types-urllib3<1.27
#   Downloading types_urllib3-1.26.25.4-py3-none-any.whl (14 kB)
# Building wheels for collected packages: pycountry
#   Building wheel for pycountry (PEP 517) ... done
#   Created wheel for pycountry: filename=pycountry-22.3.5-py2.py3-none-any.whl size=10681845 sha256=28e58de8f189c2f8ec0a02463bf4d0048115ed440d2935509e5fc7a1f36d0c0c
#   Stored in directory: /root/.cache/pip/wheels/0e/06/e8/7ee176e95ea9a8a8c3b3afcb1869f20adbd42413d4611c6eb4
# Successfully built pycountry
# Installing collected packages: types-urllib3, types-setuptools, types-requests, pycountry, gadm
# Successfully installed gadm-0.0.3 pycountry-22.3.5 types-requests-2.28.11.5 types-setuptools-65.6.0.0 types-urllib3-1.26.25.4

# %%
import requests, urllib, fastkml, geopandas as gp, folium, rasterio, rasterio.mask
from gadm import GADMDownloader
from branca.element import Figure

# %% [markdown]
# ## Administrative data

# %%
downloader = GADMDownloader(version='4.0')
kenya = downloader.get_shape_data_by_country_name(country_name='Kenya', ad_level=2)
# Out:
# 100%|██████████| 47.8M/47.8M [00:32<00:00, 1.45MB/s]

# %% [markdown]
# ## The MrGreen data
#
# Pank Seelen sent this:
#
# ---
#
# Hi Samuel,
#
# Hereby a [link to Google](https://eur04.safelinks.protection.outlook.com/?url=https%3A%2F%2Fwww.google.com%2Fmaps%2Fd%2Fu%2F0%2Fedit%3Fmid%3D1uBPMv1UM4wOshDvQf48AYzGX4iOivX0%26usp%3Dsharing&data=05%7C01%7Cj.a.s.gromicho%40uva.nl%7C37a74c6538324f218f9608dac3d9e359%7Ca0f1cacd618c4403b94576fb3d6874e5%7C0%7C0%7C638037637853280029%7CUnknown%7CTWFpbGZsb3d8eyJWIjoiMC4wLjAwMDAiLCJQIjoiV2luMzIiLCJBTiI6Ik1haWwiLCJXVCI6Mn0%3D%7C3000%7C%7C%7C&sdata=T7P4IWfCQcln6xz14Qq6dXmp1fgTmn%2BkfLmAAz7LRCk%3D&reserved=0) maps with all our collection locations:
# - Trading Points: the locations where we engage with traditional waste pickers to buy plastic from them
# - Total model: Partnerships with TotalEnergies, where we currently collect plastic from consumers at two petrol stations (plans to increase this number to 10 early next year)
# - Duka model: Duka shops that we facilitate to collect plastic from consumers
#
# Let me know if you have any questions.
#
# Pank
#
# ---
#
# Below we download that data in [KML](https://en.wikipedia.org/wiki/Keyhole_Markup_Language).

# %%
MID='1uBPMv1UM4wOshDvQf48AYzGX4iOivX0'
kml_url=f'https://www.google.com/maps/d/u/0/kml?mid={MID}&forcekml=1'

# %%
kml = fastkml.kml.KML()
kml.from_string( requests.get(kml_url).content )

# %% [markdown]
# Now we collect the coordinates into a dictionary indexed on the name.

# %%
def Collect( store, element ):
    if getattr(element, 'features', None):
        for feature in element.features():
            Collect( store, feature)
    elif getattr(element, 'geometry', None):
        store[element.name] = (element.geometry.x,element.geometry.y)
    else: 
        pass

# %%
kml_data = dict()
Collect(kml_data, kml)

# %% [markdown]
# And we put it into a dataframe.

# %%
mrgreen = gp.GeoDataFrame.from_dict( kml_data, orient='index' )
mrgreen.columns = ['lon','lat']

# %%
mrgreen
# Out:
#                                                 lon       lat
# Factory                                   36.865515 -1.328379
# 02 - Pipeline                             36.890782 -1.324501
# 08 - Eastleigh B                          36.848944 -1.266957
# 12 - Kawangware                           36.748210 -1.287301
# 16 - Kayole A                             36.922235 -1.269406
# 18 - Kayole B                             36.907241 -1.287062
# 19 - Kibera Ayany                         36.773055 -1.309143
# 20 - Kibera Lindi                         36.792899 -1.315145
# 29 - Dandora                              36.888039 -1.257197
# New TP (Tassia)                           36.898298 -1.306064
# TotalEnergies Ngong Road Service Station  36.788685 -1.299968
# Total Gigiri Service Station              36.803559 -1.232161
# Kibali General Shop                       36.690362 -1.286963
# Neema Shop                                36.871344 -1.279683
# Maragoli Shop                             36.755549 -1.279997
# Altitude Shop                             36.716546 -1.281919
# Ebenezar Shop                             36.902521 -1.259033
# Max Pablo Enterprises                     36.854118 -1.265575
# Down Town Shop                            36.835453 -1.312710
# Emmanuel 2 Shop                           36.861125 -1.258803
# White Crescent Shop                       36.810619 -1.286697
# Jakes Shop                                36.896167 -1.320667
# Samki Coke Kiosk                          36.834552 -1.309570
# Mambo Jambo Shop                          36.779224 -1.323452
# Mama Shana Shop                           36.854313 -1.261878
# Mama Euphemia Shop                        36.901181 -1.303236
# Futbol Mas - Mathare                      36.853097 -1.265192

# %% [markdown]
# ## Population data

# %%
# %%time
country = 'KEN'
worldpop_url = f'https://www.worldpop.org/rest/data/pop/wpgpunadj/?iso3={country}'
headers = {'User-Agent': 'Chrome/107.0.5304.107'}  # User-Agent is required to get API response
response = requests.get(worldpop_url, headers=headers)

# Extract url for data for the latest year
data = response.json()['data'][-1]
url = data['files'][0]
filehandle, _ = urllib.request.urlretrieve(url)
# Out:
# CPU times: user 6.88 s, sys: 3.14 s, total: 10 s
# Wall time: 9min 36s

# %%
url
# Out:
# 'https://data.worldpop.org/GIS/Population/Global_2000_2020/2020/KEN/ken_ppp_2020_UNadj.tif'

# %% [markdown]
# We got WorldPop data for year 2020.

# %%
src = rasterio.open(filehandle)
raster_tot = src.read(1)
raster_tot[raster_tot<0] = None

# %%
raster_nonzero = raster_tot[raster_tot>0]
population_worldpop = raster_nonzero.sum()
print(round(population_worldpop/1000000,2),'million')
# Out:
# 53.77 million

# %%
def get_population_count(vector_polygon,raster_layer):
    gtraster, _ = rasterio.mask.mask(raster_layer, [vector_polygon], crop=True)
    return gtraster[0][gtraster[0]>0].sum()

# %%
kenya['population'] = [ get_population_count(g,src) for g in kenya.geometry ]
nairobi = kenya[kenya.NAME_1=='Nairobi']

# %%
nairobi.population.sum()
# Out:
# 4695099.0

# %% [markdown]
# ## Showing the data so far

# %%
fig = Figure(width=800, height=600)

a,b,c,d = nairobi.geometry.unary_union.bounds 
start_coords = ((d-b)/2,(c-a)/2)
fm = folium.Map(location=start_coords)
fm.fit_bounds( ((b,a), (d,c)) )
folium.Choropleth(
    geo_data=nairobi,
    name="population count",
    data=nairobi,
    columns= ["NAME_2","population"],
    key_on="feature.properties.NAME_2",
    fill_color="Reds",
    fill_opacity=0.65,
    line_opacity=0.2,
    legend_name="Total Population in area NAME_2").add_to(fm)
fg=folium.FeatureGroup(name='MrGreen Points', show=True)
fm.add_child(fg)
for name,x,y in mrgreen.itertuples(index=True):
    folium.Marker(location=(y,x),popup=name).add_to(fg)
folium.LayerControl().add_to(fm)    
fig.add_child(fm)
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_dd42ade5ee882a02a604fdff31b7f1c1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_dd42ade5ee882a02a604fdff31b7f1c1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_dd42ade5ee882a02a604fdff31b7f1c1 = L.map(
#                 &quot;map_dd42ade5ee882a02a604fdff31b7f1c1&quot;,
#                 {
#                     center: [0.14212417600001004, 0.22011375449997672],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_026ce6195123f6e9b885478484039b77 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_dd42ade5ee882a02a604fdff31b7f1c1);
#
#
#             map_dd42ade5ee882a02a604fdff31b7f1c1.fitBounds(
#                 [[-1.4421585799999548, 36.66347503600019], [-1.1579102279999347, 37.10370254500015]],
#                 {}
#             );
#
#
#             var choropleth_1022f2e660118d9dc9f1b596da504b64 = L.featureGroup(
#                 {}
#             ).addTo(map_dd42ade5ee882a02a604fdff31b7f1c1);
#
#
#         function geo_json_731b6fe865def673935fb44db1f23246_styler(feature) {
#             switch(feature.id) {
#                 case &quot;190&quot;: case &quot;200&quot;: case &quot;204&quot;: case &quot;205&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fee5d9&quot;, &quot;fillOpacity&quot;: 0.65, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;191&quot;: case &quot;193&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#a50f15&quot;, &quot;fillOpacity&quot;: 0.65, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;194&quot;: case &quot;195&quot;: case &quot;203&quot;: case &quot;206&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fc9272&quot;, &quot;fillOpacity&quot;: 0.65, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;199&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#de2d26&quot;, &quot;fillOpacity&quot;: 0.65, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;201&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fcbba1&quot;, &quot;fillOpacity&quot;: 0.65, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fb6a4a&quot;, &quot;fillOpacity&quot;: 0.65, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_731b6fe865def673935fb44db1f23246_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_731b6fe865def673935fb44db1f23246 = L.geoJson(null, {
#                 onEachFeature: geo_json_731b6fe865def673935fb44db1f23246_onEachFeature,
#
#                 style: geo_json_731b6fe865def673935fb44db1f23246_styler,
#         });
#
#         function geo_json_731b6fe865def673935fb44db1f23246_add (data) {
#             geo_json_731b6fe865def673935fb44db1f23246
#                 .addData(data)
#                 .addTo(choropleth_1022f2e660118d9dc9f1b596da504b64);
#         }
#             geo_json_731b6fe865def673935fb44db1f23246_add({&quot;bbox&quot;: [36.66347503600019, -1.4421585799999548, 37.10370254500015, -1.1579102279999347], &quot;features&quot;: [{&quot;bbox&quot;: [36.74907684200002, -1.2978565689999755, 36.81966781700004, -1.2562378639999565], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[[36.76082229500008, -1.26816451499991], [36.7610473630001, -1.2680549619998942], [36.76158523600009, -1.2677956819998712], [36.76134109400016, -1.2676255699998933], [36.76131057800012, -1.267554758999836], [36.761142730000074, -1.267160057999945], [36.76075744700006, -1.2666475759999116], [36.76031875600012, -1.266177058999972], [36.760246278000125, -1.266098617999944], [36.76022338900009, -1.2660636889999068], [36.76003646800018, -1.2657653099998356], [36.75973510700004, -1.2652931199999102], [36.75942611700003, -1.2650561339999626], [36.75933075000006, -1.264981984999963], [36.75928497300009, -1.2649582619999364], [36.758930206000116, -1.264780640999959], [36.75843429600013, -1.2646158929999274], [36.75806808600004, -1.2644877429999042], [36.757720947000166, -1.2644877429999042], [36.75759124800004, -1.2644877429999042], [36.75722503600008, -1.2644877429999042], [36.756530761000135, -1.2645243389999337], [36.756229400000166, -1.2644547229999148], [36.756053924000184, -1.26441454899998], [36.755504608000024, -1.2641400089999024], [36.75483322200006, -1.2636547079998195], [36.75470733600014, -1.2635629169999447], [36.75450515700004, -1.2634216549998882], [36.753948213000115, -1.2632065999999327], [36.75336456300016, -1.2624012219999372], [36.75

# %%
#Proximity Analysis

# %%
print(mrgreen.crs)
# Out:
# None

# %%
MID='1uBPMv1UM4wOshDvQf48AYzGX4iOivX0'
kml_url_2=f'https://goo.gl/maps/Fe5kvofpmddQT2X98'

# %%
kml2 = fastkml.kml.KML()
kml2.from_string( requests.get(kml_url_2).content )

# %%
kml_data2 = dict()
Collect(kml_data2, kml2)

# %%
dumpsites = gp.GeoDataFrame.from_dict( kml_data2, orient='index' )
dumpsites.columns = ['lon','lat']

# %%
# Select one collection incident in particular
collection_point = mrgreen.iloc[360]

# Measure distance from site to each station
distances = mrgreen.geometry.distance(collection_point.geometry)
distances

# %%
print('Mean distance to collection stations: {} feet'.format(distances.mean()))

# %%
print('Closest collection station ({} feet):'.format(distances.min()))
print(stations.iloc[distances.idxmin()][["ADDRESS", "LATITUDE", "LONGITUDE"]])
